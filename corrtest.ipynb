# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### corr

# %%
xg = 'submissions/xgb_new_opt.csv'
lg = 'submissions/lgb_new_opt.csv'

# %%
df_xg = pd.read_csv(xg)
df_lg = pd.read_csv(lg)

# %%
df_xg.head()
# Out:
#        id      target
# 0  133627  132.391020
# 1  133629   63.860535
# 2  133630   62.935180
# 3  133631   54.773200
# 4  133633   51.771744

# %%
corr = np.corrcoef(df_xg['target'], df_lg['target'])[0, 1]
print(corr)
# Out:
# 0.9065239097927055
