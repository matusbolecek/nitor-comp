# %% [markdown]
# # Linear model for baseline comparision

# %%
import pandas as pd

# %%
from dataengineers import Dataset

# %%
dataset = Dataset('train')

# %%
train, test = dataset.build_train_test()

# %%
train.iloc[100:400]
# Out:
#        id   target  global_horizontal_irradiance  \
# 100   500   78.858                           0.0
# 101   505   84.373                           0.0
# 102   510  139.363                           0.0
# 103   515  183.848                           0.0
# 104   520  133.856                           0.0
# ..    ...      ...                           ...
# 395  1975   32.190                         501.0
# 396  1980   28.347                         605.0
# 397  1985   25.479                         690.0
# 398  1990   27.641                         683.0
# 399  1995   23.947                         600.0
#
#      diffuse_horizontal_irradiance  direct_normal_irradiance  \
# 100                            0.0                  0.000000
# 101                            0.0                  0.000000
# 102                            0.0                  0.000000
# 103                            0.0                  0.000000
# 104                            0.0                  0.000000
# ..                             ...                       ...
# 395                           67.0                951.333252
# 396                          276.0                589.197388
# 397                           83.0                994.924622
# 398                           81.0                990.444580
# 399                          101.0                904.517334
#
#      cloud_cover_total  cloud_cover_low  cloud_cover_mid  cloud_cover_high  \
# 100                0.0              0.0              0.0               0.0
# 101                0.0              0.0              0.0               0.0
# 102                0.0              0.0              0.0               0.0
# 103                0.0              0.0              0.0               0.0
# 104                0.0              0.0              0.0               0.0
# ..                 ...              ...              ...               ...
# 395               65.0              0.0              0.0              65.0
# 396               83.0              0.0              0.0              83.0
# 397                8.0              0.0              0.0               8.0
# 398                8.0              0.0              0.0               8.0
# 399               31.0              0.0              0.0              31.0
#
#      precipitation_amount  ...  load_forecast_lag_6h  load_forecast_lag_12h  \
# 100                   0.0  ...            40368.3939             38578.9435
# 101                   0.0  ...            39209.0063             39428.1093
# 102                   0.0  ...            38316.2416             41653.1812
# 103                   0.0  ...            38031.0137             42460.6279
# 104                   0.0  ...            38183.7496             42423.1529
# ..                    ...  ...                   ...                    ...
# 395                   0.0  ...            36291.6189             37058.7590
# 396                   0.0  ...            39930.7901             34827.1018
# 397                   0.0  ...            42130.8702             33707.2092
# 398                   0.0  ...            42599.2795             33097.7821
# 399                   0.0  ...            42783.9103             33329.8247
#
#      load_forecast_lag_24h  load_forecast_lag_48h  load_forecast_lag_168h  \
# 100             36017.9434             34657.1367                     NaN
# 101             38632.3005             36683.9607                     NaN
# 102             43439.7009             40617.2825                     NaN
# 103             45806.8307             42709.4816                     NaN
# 104             44568.5999             42224.5591                     NaN
# ..                     ...                    ...                     ...
# 395             44072.1249             40250.2004              44382.1402
# 396             44306.6159             40097.2839              44431.7206
# 397             44572.1793             40153.8155              44701.7405
# 398             45069.9297             40497.3020              44934.3202
# 399             45364.8617             41144.2098              45226.0899
#
#      load_forecast_rolling_mean_6h  load_forecast_rolling_mean_24h  \
# 100                   38782.177517                    40203.003633
# 101                   38672.071967                    40356.746017
# 102                   39149.937567                    40500.241825
# 103                   40391.117317                    40597.059292
# 104                   42009.283283                    40677.608408
# ..                             ...                             ...
# 395                   41148.898083                    41001.337137
# 396                   42369.830000                    40982.382367
# 397                   43086.789917                    40979.296271
# 398                   43537.984750                    40990.373767
# 399                   43982.771517                    40998.626700
#
#      load_forecast_ramp_1h  load_forecast_ramp_3h  load_forecast_ramp_6h
# 100              1123.1006              1676.7469              -660.6333
# 101              2368.4393              3892.4503              2867.1936
# 102              3687.1202              7178.6601              7447.0785
# 103              1976.6894              8032.2489              9708.9958
# 104              -743.5188              4920.2908              8812.7411
# ..                     ...                    ...                    ...
# 395               460.2909              1017.9309              7325.5915
# 396               615.3392              1448.6393              4301.7595
# 397               605.4896              1681.1197              2707.1690
# 398               429.9609              1650.7897              2668.7206
# 399               450.5795              1486.0300              2934.6693
#
# [300 rows x 87 columns]

# %%
train.isna().sum()
# Out:
# id                                 0
# target                             0
# global_horizontal_irradiance       0
# diffuse_horizontal_irradiance      0
# direct_normal_irradiance           0
#                                   ..
# load_forecast_rolling_mean_6h      5
# load_forecast_rolling_mean_24h     5
# load_forecast_ramp_1h              5
# load_forecast_ramp_3h             15
# load_forecast_ramp_6h             30
# Length: 87, dtype: int64

# %%
train.isna().sum()
# Out:
# id                                 0
# target                             0
# global_horizontal_irradiance       0
# diffuse_horizontal_irradiance      0
# direct_normal_irradiance           0
#                                   ..
# load_forecast_rolling_mean_6h      5
# load_forecast_rolling_mean_24h     5
# load_forecast_ramp_1h              5
# load_forecast_ramp_3h             15
# load_forecast_ramp_6h             30
# Length: 87, dtype: int64

# %%
test.isna().sum()
# Out:
# id                                0
# target                            0
# global_horizontal_irradiance      0
# diffuse_horizontal_irradiance     0
# direct_normal_irradiance          0
#                                  ..
# load_forecast_rolling_mean_6h     1
# load_forecast_rolling_mean_24h    1
# load_forecast_ramp_1h             1
# load_forecast_ramp_3h             3
# load_forecast_ramp_6h             6
# Length: 87, dtype: int64

# %%
train.shape
# Out:
# (106086, 87)

# %%
from models import Linear

# %%
features = [c for c in train.columns if c not in ['id', 'target', 'delivery_start', 'market']]

# %%
reg = Linear(features) # yeah linear model needs fixing
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 reg = Linear(features) # yeah linear model needs fixing
#
# File ~/repos/nitor-comp/models.py:12, in Linear.__init__(self, features)
#      11 def __init__(self, features: list):
# ---> 12     self.scaler = joblib.load('bin/scaler1.pkl')
#      13     self.scaler_features = joblib.load('bin/features1.pkl') # might break otherwise, but not an optimal solution for sure
#      14     self.model = None
#
# File ~/repos/nitor-comp/.venv/lib/python3.14/site-packages/joblib/numpy_pickle.py:735, in load(filename, mmap_mode, ensure_native_byte_order)
#     733         obj = _unpickle(fobj, ensure_native_byte_order=ensure_native_byte_order)
#     734 else:
# --> 735     with open(filename, "rb") as f:
#     736         with _validate_fileobject_and_memmap(f, filename, mmap_mode) as (
#     737             fobj,
#     738             validated_mmap_mode,
#     739         ):
#     740             if isinstance(fobj, str):
#     741                 # if the returned file object is a string, this means we
#     742                 # try to load a pickle file generated with an version of
#     743                 # Joblib so we load it with joblib compatibility function.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'bin/scaler1.pkl'

# %%
df_train = reg.process(train)
df_test = reg.process(test)

# %%
reg.fit_ridge(df_train)

# %%
ridge_vals = reg.predict(df_test)

# %%
ridge_vals
# Out:
# array([ 6.66579381, 29.61475016, 29.29765115, ..., 81.95121257,
#        86.86842728, 81.32629682], shape=(28052,))

# %%
from utils import rmse

# %%
rmse(ridge_vals, df_test['target'])
# Out:
# np.float64(60.943077237263815)

# %%
reg.fit_lr(df_train)

# %%
lr_vals = reg.predict(df_test)

# %%
rmse(lr_vals, df_test['target'])
# Out:
# np.float64(62.170233061451725)
