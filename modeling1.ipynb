# %% [markdown]
# # Linear model for baseline comparision

# %%
import pandas as pd

# %%
from dataengineers import Dataset

# %%
dataset = Dataset('train')

# %%
train, test = dataset.build_train_test()

# %%
train.iloc[100:400]
# Out:
#        market            delivery_start     id  target  \
# 100  Market A 2023-01-01 20:00:00+00:00  100.0   8.779
# 101  Market B 2023-01-01 20:00:00+00:00  101.0   8.891
# 102  Market C 2023-01-01 20:00:00+00:00  102.0   9.057
# 103  Market D 2023-01-01 20:00:00+00:00  103.0   9.100
# 104  Market E 2023-01-01 20:00:00+00:00  104.0   9.303
# ..        ...                       ...    ...     ...
# 395  Market A 2023-01-04 07:00:00+00:00  395.0  36.141
# 396  Market B 2023-01-04 07:00:00+00:00  396.0  36.748
# 397  Market C 2023-01-04 07:00:00+00:00  397.0  37.997
# 398  Market D 2023-01-04 07:00:00+00:00  398.0  38.053
# 399  Market E 2023-01-04 07:00:00+00:00  399.0  38.609
#
#      global_horizontal_irradiance  diffuse_horizontal_irradiance  \
# 100                     -0.706031                      -0.667907
# 101                     -0.706031                      -0.667907
# 102                     -0.706031                      -0.667907
# 103                     -0.706031                      -0.667907
# 104                     -0.706031                      -0.667907
# ..                            ...                            ...
# 395                     -0.706031                      -0.667907
# 396                     -0.706031                      -0.667907
# 397                     -0.706031                      -0.667907
# 398                     -0.706031                      -0.667907
# 399                     -0.706031                      -0.667907
#
#      direct_normal_irradiance  cloud_cover_total  cloud_cover_low  \
# 100                 -0.734586           1.134378        -0.558153
# 101                 -0.734586           1.706582        -0.558153
# 102                 -0.734586          -0.059787         0.220336
# 103                 -0.734586          -0.731505        -0.558153
# 104                 -0.734586           1.706582        -0.558153
# ..                        ...                ...              ...
# 395                 -0.734586          -0.607113        -0.558153
# 396                 -0.734586          -0.731505        -0.558153
# 397                 -0.734586          -0.731505        -0.558153
# 398                 -0.734586          -0.731505        -0.558153
# 399                 -0.734586          -0.731505        -0.558153
#
#      cloud_cover_mid  ...  dayofweek_sin  dayofweek_cos  month_sin  month_cos  \
# 100        -0.351047  ...      -1.104416       0.880943   0.614092   1.338484
# 101        -0.163415  ...      -1.104416       0.880943   0.614092   1.338484
# 102        -0.351047  ...      -1.104416       0.880943   0.614092   1.338484
# 103        -0.351047  ...      -1.104416       0.880943   0.614092   1.338484
# 104        -0.238468  ...      -1.104416       0.880943   0.614092   1.338484
# ..               ...  ...            ...            ...        ...        ...
# 395        -0.351047  ...       1.379735      -0.315634   0.614092   1.338484
# 396        -0.351047  ...       1.379735      -0.315634   0.614092   1.338484
# 397        -0.351047  ...       1.379735      -0.315634   0.614092   1.338484
# 398        -0.351047  ...       1.379735      -0.315634   0.614092   1.338484
# 399        -0.351047  ...       1.379735      -0.315634   0.614092   1.338484
#
#      residual  renewable_ratio  air_temperature_2m_roll_6_mean  \
# 100 -0.879498         0.762714                       -0.026208
# 101 -0.879498         0.762714                       -0.160271
# 102 -0.879498         0.762714                        0.322421
# 103 -0.879498         0.762714                        0.598675
# 104 -0.879498         0.762714                       -0.053943
# ..        ...              ...                             ...
# 395 -0.402475         0.044726                       -1.433699
# 396 -0.402475         0.044726                       -2.229157
# 397 -0.402475         0.044726                       -1.087774
# 398 -0.402475         0.044726                       -1.079141
# 399 -0.402475         0.044726                       -2.255289
#
#      wind_speed_10m_roll_6_mean  residual_roll_6_mean  market_int
# 100                    0.843436             -0.650366           0
# 101                   -0.636925             -0.650366           1
# 102                    0.422411             -0.650366           2
# 103                   -0.090023             -0.650366           3
# 104                   -0.319470             -0.650366           4
# ..                          ...                   ...         ...
# 395                    1.202661             -0.959115           0
# 396                   -0.963804             -0.959115           1
# 397                   -0.933628             -0.959115           2
# 398                   -1.198139             -0.959115           3
# 399                   -1.004677             -0.959115           4
#
# [300 rows x 45 columns]

# %%
train.isna().sum()
# Out:
# market                                   0
# delivery_start                           0
# id                                       0
# target                                   0
# global_horizontal_irradiance             0
# diffuse_horizontal_irradiance            0
# direct_normal_irradiance                 0
# cloud_cover_total                        0
# cloud_cover_low                          0
# cloud_cover_mid                          0
# cloud_cover_high                         0
# precipitation_amount                     0
# visibility                               0
# air_temperature_2m                       0
# apparent_temperature_2m                  0
# dew_point_temperature_2m                 0
# wet_bulb_temperature_2m                  0
# surface_pressure                         0
# freezing_level_height                    0
# relative_humidity_2m                     0
# convective_available_potential_energy    0
# lifted_index                             0
# convective_inhibition                    0
# wind_speed_80m                           0
# wind_direction_80m                       0
# wind_gust_speed_10m                      0
# wind_speed_10m                           0
# solar_forecast                           0
# wind_forecast                            0
# load_forecast                            0
# hour                                     0
# dayofweek                                0
# month                                    0
# hour_sin                                 0
# hour_cos                                 0
# dayofweek_sin                            0
# dayofweek_cos                            0
# month_sin                                0
# month_cos                                0
# residual                                 0
# renewable_ratio                          0
# air_temperature_2m_roll_6_mean           0
# wind_speed_10m_roll_6_mean               0
# residual_roll_6_mean                     0
# market_int                               0
# dtype: int64

# %%
train.isna().sum()
# Out:
# market                                   0
# delivery_start                           0
# id                                       0
# target                                   0
# global_horizontal_irradiance             0
# diffuse_horizontal_irradiance            0
# direct_normal_irradiance                 0
# cloud_cover_total                        0
# cloud_cover_low                          0
# cloud_cover_mid                          0
# cloud_cover_high                         0
# precipitation_amount                     0
# visibility                               0
# air_temperature_2m                       0
# apparent_temperature_2m                  0
# dew_point_temperature_2m                 0
# wet_bulb_temperature_2m                  0
# surface_pressure                         0
# freezing_level_height                    0
# relative_humidity_2m                     0
# convective_available_potential_energy    0
# lifted_index                             0
# convective_inhibition                    0
# wind_speed_80m                           0
# wind_direction_80m                       0
# wind_gust_speed_10m                      0
# wind_speed_10m                           0
# solar_forecast                           0
# wind_forecast                            0
# load_forecast                            0
# hour                                     0
# dayofweek                                0
# month                                    0
# hour_sin                                 0
# hour_cos                                 0
# dayofweek_sin                            0
# dayofweek_cos                            0
# month_sin                                0
# month_cos                                0
# residual                                 0
# renewable_ratio                          0
# air_temperature_2m_roll_6_mean           0
# wind_speed_10m_roll_6_mean               0
# residual_roll_6_mean                     0
# market_int                               0
# dtype: int64

# %%
test.isna().sum()
# Out:
# market                                   0
# delivery_start                           0
# id                                       0
# target                                   0
# global_horizontal_irradiance             0
# diffuse_horizontal_irradiance            0
# direct_normal_irradiance                 0
# cloud_cover_total                        0
# cloud_cover_low                          0
# cloud_cover_mid                          0
# cloud_cover_high                         0
# precipitation_amount                     0
# visibility                               0
# air_temperature_2m                       0
# apparent_temperature_2m                  0
# dew_point_temperature_2m                 0
# wet_bulb_temperature_2m                  0
# surface_pressure                         0
# freezing_level_height                    0
# relative_humidity_2m                     0
# convective_available_potential_energy    0
# lifted_index                             0
# convective_inhibition                    0
# wind_speed_80m                           0
# wind_direction_80m                       0
# wind_gust_speed_10m                      0
# wind_speed_10m                           0
# solar_forecast                           0
# wind_forecast                            0
# load_forecast                            0
# hour                                     0
# dayofweek                                0
# month                                    0
# hour_sin                                 0
# hour_cos                                 0
# dayofweek_sin                            0
# dayofweek_cos                            0
# month_sin                                0
# month_cos                                0
# residual                                 0
# renewable_ratio                          0
# air_temperature_2m_roll_6_mean           0
# wind_speed_10m_roll_6_mean               0
# residual_roll_6_mean                     0
# market_int                               0
# dtype: int64

# %%
train.shape
# Out:
# (106086, 45)

# %%
from models import Linear

# %%
features = [c for c in train.columns if c not in ['id', 'target', 'delivery_start', 'market']]

# %%
reg = Linear(features) # yeah linear model needs fixing
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 reg = Linear(features)
#
# File ~/repos/nitor-comp/models.py:10, in Linear.__init__(self, features)
#       9 def __init__(self, features: list):
# ---> 10     self.scaler = joblib.load('bin/scaler1.pkl')
#      11     self.scaler_features = joblib.load('bin/features1.pkl') # might break otherwise, but not an optimal solution for sure
#      12     self.model = None
#
# File ~/repos/nitor-comp/.venv/lib/python3.14/site-packages/joblib/numpy_pickle.py:735, in load(filename, mmap_mode, ensure_native_byte_order)
#     733         obj = _unpickle(fobj, ensure_native_byte_order=ensure_native_byte_order)
#     734 else:
# --> 735     with open(filename, "rb") as f:
#     736         with _validate_fileobject_and_memmap(f, filename, mmap_mode) as (
#     737             fobj,
#     738             validated_mmap_mode,
#     739         ):
#     740             if isinstance(fobj, str):
#     741                 # if the returned file object is a string, this means we
#     742                 # try to load a pickle file generated with an version of
#     743                 # Joblib so we load it with joblib compatibility function.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'bin/scaler1.pkl'

# %%
df_train = reg.process(train)
df_test = reg.process(test)

# %%
reg.fit_ridge(df_train)

# %%
ridge_vals = reg.predict(df_test)

# %%
ridge_vals
# Out:
# array([ 6.66579381, 29.61475016, 29.29765115, ..., 81.95121257,
#        86.86842728, 81.32629682], shape=(28052,))

# %%
from utils import rmse

# %%
rmse(ridge_vals, df_test['target'])
# Out:
# np.float64(60.943077237263815)

# %%
reg.fit_lr(df_train)

# %%
lr_vals = reg.predict(df_test)

# %%
rmse(lr_vals, df_test['target'])
# Out:
# np.float64(62.170233061451725)
