# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### corr

# %%
xg = 'submissions/ensemble1.csv'
lg = 'submissions/my_submission.csv'

# %%
df_xg = pd.read_csv(xg)
df_lg = pd.read_csv(lg)

# %%
df_xg.head()
# Out:
#        id      target
# 0  133627  113.726065
# 1  133629   60.092767
# 2  133630   60.683406
# 3  133631   54.155370
# 4  133633   50.513432

# %%
corr = np.corrcoef(df_xg['target'], df_lg['target'])[0, 1]
print(corr)
# Out:
# 0.9768280324137931
